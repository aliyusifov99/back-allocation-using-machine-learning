# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('trialdata.csv')

# %%
df.head()
# Out:
#            Pwf    Rate
# 0  3201.692871     0.0
# 1  3625.432129  2000.0
# 2  3733.846680  2000.0
# 3  4230.213867  2000.0
# 4  4550.829590  2000.0

# %%
sns.scatterplot(x='Pwf', y='Rate', data=df)
# Out:
# <Axes: xlabel='Pwf', ylabel='Rate'>
